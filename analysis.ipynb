# %%
import pandas as pd 
df = pd.read_csv("data/employment_by_sex.csv")
df.head()
# Out:
#               DATAFLOW        LAST UPDATE    freq  \
# 0  ESTAT:TESEM010(1.0)  29/04/26 23:00:00  Annual
# 1  ESTAT:TESEM010(1.0)  29/04/26 23:00:00  Annual
# 2  ESTAT:TESEM010(1.0)  29/04/26 23:00:00  Annual
# 3  ESTAT:TESEM010(1.0)  29/04/26 23:00:00  Annual
# 4  ESTAT:TESEM010(1.0)  29/04/26 23:00:00  Annual
#
#                                             indic_em  \
# 0  Total employment (resident population concept ...
# 1  Total employment (resident population concept ...
# 2  Total employment (resident population concept ...
# 3  Total employment (resident population concept ...
# 4  Total employment (resident population concept ...
#
#                              unit                  age      sex      geo  \
# 0  Percentage of total population  From 20 to 64 years  Females  Austria
# 1  Percentage of total population  From 20 to 64 years  Females  Austria
# 2  Percentage of total population  From 20 to 64 years  Females  Austria
# ...
